# %% [markdown]
# # **Analysis of "COVID-19 pneumonia and the subsequent risk of acquiring pulmonary tuberculosis"**
# Note that if you cannot run R in your jupyter environment, please access the following: https://drive.google.com/file/d/1fvJeXZShPmUSQiOD9IKO3hzTOzDflXl0/view?usp=sharing

# %% [markdown]
# # **Must read**

# %% [markdown]
# We recieved 2 large files from the NHSO: OP and IP databases. Both of them could be linked using hashed citizen ID. However, they could indirectly identify a person from some variable, eg, date of birth, date of service, etc. We thus de-identified them as the data provided.
#
# The data provided, the dynamic cohort, were deidentified and hashed for personal data protection. The genhash could only link individuals in the dataframe. The dataframe could not identify any person and could not be traced back. Only necessary variables were retained. Raw data can be shared upon written request to the corresponding author.

# %% [markdown]
# ### **Data dictionary**

# %% [markdown]
# **genhash** [chr]: *de-identified ID*, ie,"4b5630ee914e848e8d07221556b0a2fb", "c01f179e4b57ab8bd9de309e6d576c48"
#
# **sev** [chr]: *COVID-19 status*: "Population control", "Negative control", "Asymptomatic", "Symptomatic non-pneumonia", "Pneumonia", "Severe pneumonia"
#
# **sevm** [fct]: *COVID-19 status used for analysis (pneumonia and severe pneumonia were combined)*: "Population control", "Negative control", "Asymptomatic", "Symptomatic non-pneumonia", "Pneumonia"
#
# **coviddeath** [lgl]: *Status at discharge for hospitalised patients with COVID-19*
# - FALSE: survive
# - TRUE: dead
# - NA: no COVID-19
#
# **LOS** [int]: *Length of hospital stay* (days from COVID-19 detection to discharge with recovery/death, all refered hospital data were summed up)
# - NA: no COVID-19
#
# **timetoevent** [dbl]: *Days from starting follow up for each individual to TB detection or censor* (censor: any cause of death/COVID-19 status changed/end of study)
#
# **tb** [lgl]: *TB detection at time to event*
# - FALSE: not detected
# - TRUE: detected
#
# **sex** [lgl]: *Male or not*
# - FALSE: Female
# - TRUE: Male
#
# **age **[fct]: *Age group*: 18-40, 41-60, >60
#
# **hiv** [lgl]: *HIV infection* (patients in HIV registration)
# - FALSE: not infected
# - TRUE: infected
#
# **dm** [lgl]: *Underlying Diabetes mellitus* (patients in DM registration)
# - FALSE: no DM
# - TRUE: DM
#
# **cancer** [lgl]: *Underlying any cancer* (patients in cancer registration)
# - FALSE: no cancer
# - TRUE: any cancer
#
# **copd** [lgl]: *Underlying chronic obstructive Chronic Obstructive Pulmonary Disease* (patients in COPD registration)
# - FALSE: no COPD
# - TRUE: COPD
#
# **recv** [lgl]: *COVID-19 reinfection only for the patients who had COVID-19 before October 1, 2021*
# - FALSE: no reinfection
# - TRUE: reinfection
#
# **timetorecv**  [dbl]: *days from the first COVID-19 infection detected to the second COVID-19 infection detected*
#
# NA for individuals without COVID-19 reinfection

# %% [markdown]
# **Preparation**

# %% [markdown]
# Install libraries for data analysis

# %%
install.packages("tidyverse")
install.packages("readxl")
install.packages("stringr")
install.packages("ggpubr")
install.packages("survminer")
install.packages("epiDisplay")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘numDeriv’, ‘SparseM’, ‘MatrixModels’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘carData’, ‘abind’, ‘pbkrtest’, ‘quantreg’, ‘lme4’, ‘Rcpp’, ‘corrplot’, ‘car’, ‘ggrepel’, ‘ggsci’, ‘cowplot’, ‘ggsignif’, ‘gridExtra’, ‘polynom’, ‘rstatix’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘markdown’, ‘png’, ‘jpeg’, ‘exactRankTests’, ‘mvtnorm’, ‘KMsurv’, ‘zoo’, ‘km.ci’, ‘xtable’, ‘gridtext’, ‘maxstat’, ‘survMisc’, ‘ggtext’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("EValue")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘mathjaxr’, ‘pbapply’, ‘metafor’, ‘metadat’, ‘MetaUtility’

# %% [markdown]
# Import the essential libraries

# %%
library(tidyverse)
library(data.table)
library(readxl)
library(lubridate)
library(stringr)
library(survminer)
library(epiDisplay)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Loading required package: timechange
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union
#
#
# Loading required package: ggpubr
#
# Loading required package: foreign
#
# Loading required package: survival
#
#
# Attaching package: ‘survival’
#
#
# The following object is masked from ‘package:survminer’:
#
#     myeloma
#
#
# Loading required package: MASS
#
#
# Attaching package: ‘MASS’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# Loading required package: nnet
#
#
# Attaching package: ‘epiDisplay’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     alpha

# %%
library(EValue)

# %% [markdown]
# **Import data**

# %% [markdown]
# Note that we import data from an online source that can be expired. Data will be re-uploaded upon written request to the corresponding author.

# %% [markdown]
# *import claim data*

# %%
temp <- tempfile()
download.file("https://drive.google.com/uc?id=1rzkpfRRtyXNFzpUgAZZ-AySs4TNITOFf&authuser=0&export=download&confirm=t&uuid=2e032824-752e-486f-be25-9552dd5eb829", temp)
hhr<-readRDS(temp)

# %% [markdown]
# **Descriptive information**

# %% [markdown]
# *Number of individuals in the dynamic cohort*

# %% [markdown]
# Note that each individual could be in more than one COVID-19 status, for example, population control -> negative control -> asymptomatic COVID-19

# %%
nrow(unique(hhr,by="genhash"))
# Out:
# [1] 4241201

# %%
tab1(hhr$sev)
# Out:
# hhr$sev :
#                           Frequency Percent Cum. percent
# Asymptomatic                  54286     1.3          1.3
# Negative control             384423     8.9         10.2
# Pneumonia                     23799     0.6         10.8
# Population control          3818612    88.8         99.6
# Severe pneumonia                818     0.0         99.6
# Symptomatic non-pneumonia     16935     0.4        100.0
#   Total                     4298873   100.0        100.0
# Plot with title “Distribution of hhr$sev”

# %%
tab1(hhr[tb==TRUE]$sev)
# Out:
# hhr[tb == TRUE]$sev :
#                           Frequency Percent Cum. percent
# Asymptomatic                     23     0.8          0.8
# Negative control                170     6.3          7.1
# Pneumonia                        69     2.5          9.7
# Population control             2423    89.4         99.0
# Severe pneumonia                  6     0.2         99.3
# Symptomatic non-pneumonia        20     0.7        100.0
#   Total                        2711   100.0        100.0
# Plot with title “Distribution of hhr[tb == TRUE]$sev”

# %%
tabpct(hhr$sev,hhr$coviddeath)
# Out:
# Original table
#                            hhr$coviddeath
# hhr$sev                      FALSE   TRUE  Total
#   Asymptomatic               45549     11  45560
#   Negative control               0      0      0
#   Pneumonia                  23357    442  23799
#   Population control             0      0      0
#   Severe pneumonia             411    407    818
#   Symptomatic non-pneumonia  16890     45  16935
#   Total                      86207    905  87112
#
# Row percent
#                            hhr$coviddeath
# hhr$sev                       FALSE    TRUE  Total
#   Asymptomatic                45549      11  45560
#                               (100)     (0)  (100)
#   Negative control                0       0      0
#                               (NaN)   (NaN)  (100)
#   Pneumonia                   23357     442  23799
#                              (98.1)   (1.9)  (100)
#   Population control              0       0      0
#                               (NaN)   (NaN)  (100)
#   Severe pneumonia              411     407    818
#                              (50.2)  (49.8)  (100)
#   Symptomatic non-pneumonia   16890      45  16935
#                              (99.7)   (0.3)  (100)
#
# Column percent
#                            hhr$coviddeath
# hhr$sev                      FALSE       %  TRUE       %
#   Asymptomatic               45549  (52.8)    11   (1.2)
#   Negative control               0   (0.0)     0   (0.0)
#   Pneumonia                  23357  (27.1)   442  (48.8)
#   Population control             0   (0.0)     0   (0.0)
#   Severe pneumonia             411   (0.5)   407  (45.0)
#   Symptomatic non-pneumonia  16890  (19.6)    45   (5.0)
#   Total                      86207   (100)   905   (100)
# Plot with title “Distribution of hhr$coviddeath by hhr$sev”

# %% [markdown]
# *Person-years contributed by each exposured group*

# %%
fig2<-summary(pyears(Surv(timetoevent/365, tb) ~ sev,data = hhr,scale = 1))
print("====")
round(fig2$pyear,0)
print(paste0("Sum of all:", sum(round(fig2$pyear,0))))
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sev, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
#             sev                 N      Events       Time
# --------------------------- --------- -------- --------------
#        Asymptomatic            54286      23      34251.4192
#      Negative control         384423     170     227917.6219
#          Pneumonia             23799      69      13916.3479
#     Population control       3818612    2423    3108224.1560
#      Severe pneumonia            818       6        243.2932
#  Symptomatic non-pneumonia     16935      20      10325.1836
# [1] "===="
# sev
#              Asymptomatic          Negative control                 Pneumonia
#                     34251                    227918                     13916
#        Population control          Severe pneumonia Symptomatic non-pneumonia
#                   3108224                       243                     10325
# [1] "Sum of all:3394877"

# %% [markdown]
# *There were only 6 events in the severe pneumonia group, so we combined it with the pneumonia group.*

# %% [markdown]
# *Person-years contributed by each exposure group* **(for analysis)**

# %%
fig2<-summary(pyears(Surv(timetoevent/365, tb) ~ sevm,data = hhr,scale = 1))
print("====")
round(fig2$pyear,0)
print(paste0("Sum of all:", sum(round(fig2$pyear,0))))
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sevm, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
#            sevm                 N      Events      Time
# --------------------------- --------- -------- ------------
#     Population control       3818612    2423    3108224.16
#      Negative control         384423     170     227917.62
#        Asymptomatic            54286      23      34251.42
#  Symptomatic non-pneumonia     16935      20      10325.18
#          Pneumonia             24617      75      14159.64
# [1] "===="
# sevm
#        Population control          Negative control              Asymptomatic
#                   3108224                    227918                     34251
# Symptomatic non-pneumonia                 Pneumonia
#                     10325                     14160
# [1] "Sum of all:3394878"

# %% [markdown]
# **Demographic information**

# %% [markdown]
# # Demographic table

# %%
tableStack(8:13,by=sev,data=hhr)
# Out:
#          Asymptomatic Negative control Pneumonia    Population control
# Total    54286        384423           23799        3818612
#
# sex
#    FALSE 38552 (71)   212322 (55.2)    16273 (68.4) 2052265 (53.7)
#    TRUE  15734 (29)   172101 (44.8)    7526 (31.6)  1766347 (46.3)
#
# age
#    18-40 41316 (76.1) 201771 (52.5)    10773 (45.3) 1745880 (45.7)
#    41-60 10247 (18.9) 128483 (33.4)    7380 (31)    1285773 (33.7)
#    >60   2723 (5)     54169 (14.1)     5646 (23.7)  786959 (20.6)
#
# hiv
#    FALSE 54080 (99.6) 382162 (99.4)    23684 (99.5) 3796879 (99.4)
#    TRUE  206 (0.4)    2261 (0.6)       115 (0.5)    21733 (0.6)
#
# dm
#    FALSE 52664 (97)   358442 (93.2)    20405 (85.7) 3573588 (93.6)
#    TRUE  1622 (3)     25981 (6.8)      3394 (14.3)  245024 (6.4)
#
# cancer
#    FALSE 54052 (99.6) 377053 (98.1)    23492 (98.7) 3747832 (98.1)
#    TRUE  234 (0.4)    7370 (1.9)       307 (1.3)    70780 (1.9)
#
# copd
#    No    54082 (99.6) 379416 (98.7)    23254 (97.7) 3772997 (98.8)
#    Yes   204 (0.4)    5007 (1.3)       545 (2.3)    45615 (1.2)
#
#          Severe pneumonia Symptomatic non-pneumonia Test stat.
# Total    818              16935
#
# sex                                                 Chisq. (5 df) = 11112.21
#    FALSE 483 (59)         12428 (73.4)
#    TRUE  335 (41)         4507 (26.6)
#
# age                                                 Chisq. (10 df) = 34921.54
#    18-40 169 (20.7)       11833 (69.9)
#    41-60 283 (34.6)       3435 (20.3)
#    >60   366 (44.7)       1667 (9.8)
#
# hiv                                                 Chisq. (5 df) = 55.9
#    FALSE 815 (99.6)       16877 (99.7)
#    TRUE  3 (0.4)          58 (0.3)
#
# dm                                                  Chisq. (5 df) = 4357.44
#    FALSE 571 (69.8)       16042 (94.7)
#    TRUE  247 (30.2)       893 (5.3)
#
# cancer                                              Chisq. (5 df) = 791.99
#    FALSE 805 (98.4)       16828 (99.4)
#    TRUE  13 (1.6)         107 (0.6)
#
# copd                                                Chisq. (5 df) = 635.5
#    No    787 (96.2)       16699 (98.6)
#    Yes   31 (3.8)         236 (1.4)
#
#          P value
# Total
#
# sex      < 0.001
#    FALSE
#    TRUE
#
# age      < 0.001
#    18-40
#    41-60
#    >60
#
# hiv      < 0.001
#    FALSE
#    TRUE
#
# dm       < 0.001
#    FALSE
#    TRUE
#
# cancer   < 0.001
#    FALSE
#    TRUE
#
# copd     < 0.001
#    No
#    Yes

# %% [markdown]
# *Age could not be shown in this file; some individuals with extreme ages can be identified.*

# %%
#tapply(hhr$age, hhr$sev, summary)

# %% [markdown]
# Here is the result.

# %% [markdown]
# ![addition.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *Sex (person-years contributed)*

# %%
summary(pyears(Surv(timetoevent/365, tb) ~ sevm+sex,data = hhr,scale = 1))
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sevm + sex, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
# ------
#   N
# Events
#  Time
# ------
#
# -------------------------------------------------
#                               sex
#           sevm               FALSE       TRUE
# ------------------------- ----------- -----------
#                             2052265     1766347
#    Population control           659        1764
#                           1670431.899 1437792.258
#
#                              212322      172101
#     Negative control             54         116
#                            124811.167  103106.455
#
#                               38552       15734
#       Asymptomatic               11          12
#                             24244.545   10006.874
#
#                               12428        4507
# Symptomatic non-pneumonia         6          14
#                              7583.921    2741.263
#
#                               16756        7861
#         Pneumonia                19          56
#                              9706.756    4452.885
# -------------------------------------------------

# %%
options(scipen=999)
summary(pyears(Surv(timetoevent/365, tb) ~ sev+sex,data = hhr,scale = 1))
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sev + sex, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
# ------
#   N
# Events
#  Time
# ------
#
# -----------------------------------------------------
#                                sex
#            sev                FALSE         TRUE
# ------------------------- ------------- -------------
#                                38552         15734
#       Asymptomatic                11            12
#                             24244.54521   10006.87397
#
#                               212322        172101
#     Negative control              54           116
#                            124811.16712  103106.45479
#
#                                16273          7526
#         Pneumonia                 17            52
#                              9545.88219    4370.46575
#
#                              2052265       1766347
#    Population control            659          1764
#                           1670431.89860 1437792.25753
#
#                                  483           335
#     Severe pneumonia               2             4
#                               160.87397      82.41918
#
#                                12428          4507
# Symptomatic non-pneumonia          6            14
#                              7583.92055    2741.26301
# -----------------------------------------------------

# %% [markdown]
# *Death from COVID-19 among the cohort*

# %%
dat1<-hhr[!(sev %in% c("Population control","Negative control")),]
dead<-summary(pyears(Surv(LOS/365, coviddeath) ~ sev,data = dat1,scale = 1))
round(dead$event/dead$pyears*100,2)
# Out:
# Call: pyears(formula = Surv(LOS/365, coviddeath) ~ sev, data = dat1,
#     scale = 1)
#
# number of observations = 87112
#
#             sev                N     Events      Time
# --------------------------- ------- -------- ------------
#        Asymptomatic          45560     11     1821.20548
#          Pneumonia           23799    442      971.05205
#      Severe pneumonia          818    407       50.72329
#  Symptomatic non-pneumonia   16935     45      678.41096
# sev
#              Asymptomatic                 Pneumonia          Severe pneumonia
#                      0.60                     45.52                    802.39
# Symptomatic non-pneumonia
#                      6.63

# %%
nrow(unique(hhr[sev=="Severe pneumonia"],by="genhash"))
# Out:
# [1] 800

# %% [markdown]
# *LOS*

# %%
tapply(hhr[!(sev %in% c("Population control","Negative control")) & coviddeath==FALSE]$LOS, hhr[!(sev %in% c("Population control","Negative control")) & coviddeath==FALSE]$sev, ci)
# Out:
# $Asymptomatic
#      n     mean       sd          se lower95ci upper95ci
#  45549 14.59031 1.533873 0.007187037  14.57622   14.6044
#
# $Pneumonia
#      n     mean       sd         se lower95ci upper95ci
#  23357 14.87644 2.273904 0.01487865  14.84728   14.9056
#
# $`Severe pneumonia`
#    n     mean       sd       se lower95ci upper95ci
#  411 27.99027 22.51698 1.110681  25.80693  30.17361
#
# $`Symptomatic non-pneumonia`
#      n     mean       sd         se lower95ci upper95ci
#  16890 14.62007 1.830832 0.01408749  14.59246  14.64768

# %% [markdown]
# *COVID-19 reinfection*

# %%
reinf<-summary(pyears(Surv(timetorecv/365, recv) ~ sev,data = dat1,scale = 1))
round(reinf$event/reinf$pyears*100,2)
# Out:
# Call: pyears(formula = Surv(timetorecv/365, recv) ~ sev, data = dat1,
#     scale = 1)
#
# number of observations = 95838
#
#             sev                N     Events      Time
# --------------------------- ------- -------- ------------
#        Asymptomatic          54286    1081    34401.7726
#          Pneumonia           23799     532    14343.4329
#      Severe pneumonia          818       6      511.3068
#  Symptomatic non-pneumonia   16935     299    10408.5726
# sev
#              Asymptomatic                 Pneumonia          Severe pneumonia
#                      3.14                      3.71                      1.17
# Symptomatic non-pneumonia
#                      2.87

# %% [markdown]
# *HIV infection*

# %%
summary(pyears(Surv(timetoevent/365, tb) ~ sevm+hiv,data = hhr,scale = 1))
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sevm + hiv, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
# ------
#   N
# Events
#  Time
# ------
#
# ---------------------------------------------------
#                               hiv
#           sevm               FALSE         TRUE
# ------------------------- ------------ ------------
#                             3796879        21733
#    Population control          2304          119
#                           3.090629e+06 1.759523e+04
#
#                              382162         2261
#     Negative control            159           11
#                           2.265953e+05 1.322290e+03
#
#                               54080          206
#       Asymptomatic               21            2
#                           3.411069e+04 1.407260e+02
#
#                               16877           58
# Symptomatic non-pneumonia        18            2
#                           1.029060e+04 3.458630e+01
#
#                               24499          118
#         Pneumonia                70            5
#                           1.409120e+04 6.843836e+01
# ---------------------------------------------------

# %%
options(scipen=999)
summary(pyears(Surv(timetoevent/365, tb) ~ sev+hiv,data = hhr,scale = 1))
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sev + hiv, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
# ------
#   N
# Events
#  Time
# ------
#
# ---------------------------------------------------------
#                                 hiv
#            sev                 FALSE           TRUE
# ------------------------- --------------- ---------------
#                                 54080             206
#       Asymptomatic                 21               2
#                             34110.6931507     140.7260274
#
#                                382162            2261
#     Negative control              159              11
#                            226595.3315067    1322.2904110
#
#                                 23684             115
#         Pneumonia                  64               5
#                             13848.4739726      67.8739726
#
#                               3796879           21733
#    Population control            2304             119
#                           3090628.9231401   17595.2328767
#
#                                   815               3
#     Severe pneumonia                6               0
#                               242.7287671       0.5643836
#
#                                 16877              58
# Symptomatic non-pneumonia          18               2
#                             10290.5972603      34.5863014
# ---------------------------------------------------------

# %% [markdown]
# *DM*

# %%
summary(pyears(Surv(timetoevent/365, tb) ~ sevm+dm,data = hhr,scale = 1))
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sevm + dm, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
# ------
#   N
# Events
#  Time
# ------
#
# ---------------------------------------------------
#                                dm
#           sevm               FALSE         TRUE
# ------------------------- ------------ ------------
#                             3573588       245024
#    Population control          2032          391
#                           2910053.5971  198170.5589
#
#                              358442        25981
#     Negative control            142           28
#                            213395.7836   14521.8384
#
#                               52664         1622
#       Asymptomatic               19            4
#                             33246.5370    1004.8822
#
#                               16042          893
# Symptomatic non-pneumonia        14            6
#                              9782.6932     542.4904
#
#                               20976         3641
#         Pneumonia                54           21
#                             12195.1808    1964.4603
# ---------------------------------------------------

# %%
summary(pyears(Surv(timetoevent/365, tb) ~ sev+dm,data = hhr,scale = 1))
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sev + dm, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
# ------
#   N
# Events
#  Time
# ------
#
# -----------------------------------------------------
#                                dm
#            sev                FALSE         TRUE
# ------------------------- ------------- -------------
#                                52664          1622
#       Asymptomatic                19             4
#                             33246.53699    1004.88219
#
#                               358442         25981
#     Negative control             142            28
#                            213395.78356   14521.83836
#
#                                20405          3394
#         Pneumonia                 49            20
#                             12008.74247    1907.60548
#
#                              3573588        245024
#    Population control           2032           391
#                           2910053.59713  198170.55890
#
#                                  571           247
#     Severe pneumonia               5             1
#                               186.43836      56.85479
#
#                                16042           893
# Symptomatic non-pneumonia         14             6
#                              9782.69315     542.49041
# -----------------------------------------------------

# %% [markdown]
# *Any cancer*

# %%
summary(pyears(Surv(timetoevent/365, tb) ~ sevm+cancer,data = hhr,scale = 1))
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sevm + cancer, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
# ------
#   N
# Events
#  Time
# ------
#
# ---------------------------------------------------
#                              cancer
#           sevm               FALSE         TRUE
# ------------------------- ------------ ------------
#                             3747832        70780
#    Population control          2320          103
#                           3.050945e+06 5.727913e+04
#
#                              377053         7370
#     Negative control            152           18
#                           2.235849e+05 4.332732e+03
#
#                               54052          234
#       Asymptomatic               23            0
#                           3.410430e+04 1.471151e+02
#
#                               16828          107
# Symptomatic non-pneumonia        19            1
#                           1.026224e+04 6.294795e+01
#
#                               24297          320
#         Pneumonia                72            3
#                           1.399392e+04 1.657178e+02
# ---------------------------------------------------

# %%
summary(pyears(Surv(timetoevent/365, tb) ~ sev+cancer,data = hhr,scale = 1))
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sev + cancer, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
# ------
#   N
# Events
#  Time
# ------
#
# -------------------------------------------------------
#                               cancer
#            sev                FALSE           TRUE
# ------------------------- -------------- --------------
#                                54052            234
#       Asymptomatic                23              0
#                             34104.304110     147.115068
#
#                               377053           7370
#     Negative control             152             18
#                            223584.890411    4332.731507
#
#                                23492            307
#         Pneumonia                 66              3
#                             13753.780822     162.567123
#
#                              3747832          70780
#    Population control           2320            103
#                           3050945.024513   57279.131507
#
#                                  805             13
#     Severe pneumonia               6              0
#                               240.142466       3.150685
#
#                                16828            107
# Symptomatic non-pneumonia         19              1
#                             10262.235616      62.947945
# -------------------------------------------------------

# %% [markdown]
# *COPD*

# %%
summary(pyears(Surv(timetoevent/365, tb) ~ sevm+copd,data = hhr,scale = 1))
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sevm + copd, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
# ------
#   N
# Events
#  Time
# ------
#
# ---------------------------------------------------
#                               copd
#           sevm               FALSE         TRUE
# ------------------------- ------------ ------------
#                             3772997        45615
#    Population control          2304          119
#                           3071418.2163   36805.9397
#
#                              379416         5007
#     Negative control            159           11
#                            225200.6082    2717.0137
#
#                               54082          204
#       Asymptomatic               20            3
#                             34125.1836     126.2356
#
#                               16699          236
# Symptomatic non-pneumonia        15            5
#                             10185.7918     139.3918
#
#                               24041          576
#         Pneumonia                71            4
#                             13857.7397     301.9014
# ---------------------------------------------------

# %%
options(scipen=999)
summary(pyears(Surv(timetoevent/365, tb) ~ sev+copd,data = hhr,scale = 1))
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sev + copd, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
# ------
#   N
# Events
#  Time
# ------
#
# -------------------------------------------------------
#                                copd
#            sev                FALSE           TRUE
# ------------------------- -------------- --------------
#                                54082            204
#       Asymptomatic                20              3
#                             34125.183562     126.235616
#
#                               379416           5007
#     Negative control             159             11
#                            225200.608219    2717.013699
#
#                                23254            545
#         Pneumonia                 66              3
#                             13621.917808     294.430137
#
#                              3772997          45615
#    Population control           2304            119
#                           3071418.216292   36805.939726
#
#                                  787             31
#     Severe pneumonia               5              1
#                               235.821918       7.471233
#
#                                16699            236
# Symptomatic non-pneumonia         15              5
#                             10185.791781     139.391781
# -------------------------------------------------------

# %% [markdown]
# Time between SARS-CoV-2 infection and TB diagnosis among those who experience the outcome?

# %%
mean(hhr[tb==TRUE]$timetoevent)
# Out:
# [1] 164.5574

# %%
summary(hhr[tb==TRUE]$timetoevent)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     2.0    97.0   175.0   164.6   237.0   299.0

# %%
sd(hhr[tb==TRUE]$timetoevent)
# Out:
# [1] 85.08629

# %%
data.frame(severity=names(tapply(hhr[tb==TRUE]$timetoevent,hhr[tb==TRUE]$sevm,mean)),mean.time=tapply(hhr[tb==TRUE]$timetoevent,hhr[tb==TRUE]$sevm,mean),
sd.time=tapply(hhr[tb==TRUE]$timetoevent,hhr[tb==TRUE]$sevm,sd))
# Out:
#                           severity                  mean.time sd.time
# Population control        Population control        168.6735  84.19220
# Negative control          Negative control          120.7059  83.29541
# Asymptomatic              Asymptomatic              158.9130  82.44277
# Symptomatic non-pneumonia Symptomatic non-pneumonia 174.1000  81.65260
# Pneumonia                 Pneumonia                 130.1600  85.70866

# %%
tapply(hhr[tb==TRUE]$timetoevent, hhr[tb==TRUE]$sev, summary)
# Out:
# $Asymptomatic
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     8.0   109.0   160.0   158.9   226.5   277.0
#
# $`Negative control`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    2.00   40.25  112.00  120.71  186.00  297.00
#
# $Pneumonia
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     2.0    41.0   123.0   129.8   205.0   277.0
#
# $`Population control`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     2.0   103.0   180.0   168.7   239.0   299.0
#
# $`Severe pneumonia`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   10.00   44.75  138.00  134.50  205.00  280.00
#
# $`Symptomatic non-pneumonia`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    19.0   114.8   192.0   174.1   242.2   288.0

# %% [markdown]
# **Visualisation**

# %% [markdown]
# We applied the Nelson–Aalen method to create cumulative PTB incidence per 100,000 population.

# %%
options(repr.plot.width=23, repr.plot.height=11)
safe_colorblind_palette <- c("#88CCEE", "#CC6677", "#DDCC77","#332288", "#117733",  "#AA4499", 
                             "#44AA99", "#999933", "#882255", "#661100", "#6699CC", "#888888")
fit3 <- survfit(Surv(timetoevent, tb) ~ sevm, data = hhr)
fig3<-ggsurvplot(
  fit3,
  data = hhr,             # Add p-value
  fun ="cumhaz",
  censor = FALSE,
  palette = safe_colorblind_palette,
  legend.labs = c("Population control (reference)", 
                  "Negative control", "Asymptomatic", 
                  "Symptomatic non-pneumonia        ","Pneumonia"),
  risk.table = TRUE,
  risk.table.col = "black", risk.table.fontsize = 4,
  legend.title = "",
  size=1.7,
  surv.scale ="percent",
  break.time.by = 30,
  legend= c(0.35,0.9),
  ggtheme = theme_classic()      # Change ggplot2 theme
)
p3<-fig3$plot + guides(colour = guide_legend(nrow = 3,reverse = TRUE))+
  scale_x_continuous(name = "Days of follow up",breaks = 1:9*30,limits = c(0,300),expand = c(0,0))+
  scale_y_continuous(name= "Cumulative pulmonary tuberculosis incidence rate per 100 000 person-years",breaks = 1:7*0.001,limits = c(0,7*0.001+0.0001),labels = scales::label_number(scale = 1e5),expand = c(0,0))+
  theme(legend.text = element_text(size=25),
        legend.key = element_rect(fill = "transparent",colour ="transparent"),
        axis.text.x = element_text(size=20),
        axis.text.y = element_text(size=20),
        axis.title.x = element_text(size=17),
        axis.title.y = element_text(size=17))
fig3t<-ggsurvplot(
  fit3,
  data = hhr,             # Add p-value
  fun ="cumhaz",
  censor = FALSE,
  palette = c("black","black","black","black","black"),
  legend.labs = c("Population control (reference)", 
                  "Negative control", "Asymptomatic", 
                  "Symptomatic non-pneumonia","Pneumonia"),
  risk.table = TRUE,
  risk.table.col = "black", risk.table.fontsize = 4,
  legend.title = "",
  xlab="Days of follow up",
  size=1.7,
  surv.scale ="percent",
  xlim=c(0,270),
  break.time.by = 30,
  legend= c(0.15,0.9),
  ggtheme = theme_classic()      # Change ggplot2 theme
)
customize_labels <- function (p, font.title = NULL,
                              font.subtitle = NULL, font.caption = NULL,
                              font.x = NULL, font.y = NULL, font.xtickslab = NULL, font.ytickslab = NULL)
{
  original.p <- p
  if(is.ggplot(original.p)) list.plots <- list(original.p)
  else if(is.list(original.p)) list.plots <- original.p
  else stop("Can't handle an object of class ", class (original.p))
  .set_font <- function(font){
    font <- ggpubr:::.parse_font(font)
    ggtext::element_markdown (size = font$size, face = font$face, colour = font$color)
  }
  for(i in 1:length(list.plots)){
    p <- list.plots[[i]]
    if(is.ggplot(p)){
      if (!is.null(font.title)) p <- p + theme(plot.title = .set_font(font.title))
      if (!is.null(font.subtitle)) p <- p + theme(plot.subtitle = .set_font(font.subtitle))
      if (!is.null(font.caption)) p <- p + theme(plot.caption = .set_font(font.caption))
      if (!is.null(font.x)) p <- p + theme(axis.title.x = .set_font(font.x))
      if (!is.null(font.y)) p <- p + theme(axis.title.y = .set_font(font.y))
      if (!is.null(font.xtickslab)) p <- p + theme(axis.text.x = .set_font(font.xtickslab))
      if (!is.null(font.ytickslab)) p <- p + theme(axis.text.y = .set_font(font.ytickslab))
      list.plots[[i]] <- p
    }
  }
  if(is.ggplot(original.p)) list.plots[[1]]
  else list.plots
}
fig3t <- customize_labels(
  fig3t,
  font.title    = c(20 ),
  font.subtitle = c(17 ),
  font.caption  = c(17 ),
  font.x        = c(17 ),
  font.ytickslab = c(17),
  font.xtickslab = c(17)
)
transparent_theme <- theme(
  panel.background = element_rect(fill = "transparent",colour = NA),
  plot.background = element_rect(fill = "transparent",colour = NA),
  plot.margin=unit(c(0,0,0,0),"mm"),)
fig3tt<-fig3t$table+transparent_theme

p3 + annotation_custom(grob = ggplotGrob(fig3tt), xmin = 3,xmax = 220, 
                       ymin = 0.0028, ymax = 0.0055)
# Out:
# Scale for 'x' is already present. Adding another scale for 'x', which will
# replace the existing scale.
#
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
# plot without title

# %% [markdown]
# **Cox's regression**

# %% [markdown]
# We initially performed multiple Cox’s regression and check the assumption of proportional hazard.

# %%
coxm <- coxph(Surv(timetoevent, tb) ~ sevm+sex+age+hiv+dm+cancer+copd, data = hhr)
summary(coxm)
cox.zph(coxm)
# Out:
# Call:
# coxph(formula = Surv(timetoevent, tb) ~ sevm + sex + age + hiv +
#     dm + cancer + copd, data = hhr)
#
#   n= 4298873, number of events= 2711
#
#                                  coef exp(coef) se(coef)      z Pr(>|z|)
# sevmNegative control          0.03587   1.03652  0.07974  0.450    0.653
# sevmAsymptomatic              0.30680   1.35907  0.21010  1.460    0.144
# sevmSymptomatic non-pneumonia 1.31826   3.73690  0.22502  5.858 4.68e-09 ***
# sevmPneumonia                 2.01454   7.49726  0.11823 17.038  < 2e-16 ***
# sexTRUE                       1.14903   3.15512  0.04326 26.562  < 2e-16 ***
# age41-60                      0.38176   1.46486  0.04671  8.174 2.99e-16 ***
# age>60                        0.42369   1.52758  0.05475  7.739 1.00e-14 ***
# hivTRUE                       2.13346   8.44406  0.08798 24.251  < 2e-16 ***
# dmTRUE                        0.91489   2.49651  0.05517 16.582  < 2e-16 ***
# cancerTRUE                    0.71857   2.05150  0.09315  7.714 1.22e-14 ***
# copdTRUE                      0.93329   2.54287  0.08961 10.415  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#                               exp(coef) exp(-coef) lower .95 upper .95
# sevmNegative control              1.037     0.9648    0.8866     1.212
# sevmAsymptomatic                  1.359     0.7358    0.9003     2.052
# sevmSymptomatic non-pneumonia     3.737     0.2676    2.4042     5.808
# sevmPneumonia                     7.497     0.1334    5.9465     9.452
# sexTRUE                           3.155     0.3169    2.8986     3.434
# age41-60                          1.465     0.6827    1.3367     1.605
# age>60                            1.528     0.6546    1.3722     1.701
# hivTRUE                           8.444     0.1184    7.1067    10.033
# dmTRUE                            2.497     0.4006    2.2406     2.782
# cancerTRUE                        2.052     0.4874    1.7091     2.462
# copdTRUE                          2.543     0.3933    2.1333     3.031
#
# Concordance= 0.714  (se = 0.005 )
# Likelihood ratio test= 1988  on 11 df,   p=<2e-16
# Wald test            = 2529  on 11 df,   p=<2e-16
# Score (logrank) test = 3167  on 11 df,   p=<2e-16
#         chisq df       p
# sevm   24.624  4 6.0e-05
# sex     3.005  1  0.0830
# age     0.273  2  0.8723
# hiv     2.380  1  0.1229
# dm      1.227  1  0.2681
# cancer 10.244  1  0.0014
# copd    6.410  1  0.0113
# GLOBAL 49.816 11 6.8e-07

# %% [markdown]
# # **Diagnostics for Cox's model**

# %% [markdown]
# log(-log(S(t))) vs log(t)

# %%
options(repr.plot.width=40, repr.plot.height=15)
fit3 <- survfit(Surv(timetoevent, tb) ~ sevm, data = hhr)
fig3<-ggsurvplot(
  fit3,
  data = hhr, 
  fun ="cloglog",
  conf.int = TRUE,
  censor = FALSE,
  palette = safe_colorblind_palette,
  legend.labs = c("Population control (reference)", 
                  "Negative control", "Asymptomatic", 
                  "Symptomatic non-pneumonia        ","Pneumonia"),
  legend.title = "",
  size=1.7,
  break.time.by = 30,
  legend= c(0.35,0.9),
  ggtheme = theme_classic()      # Change ggplot2 theme
)
fig3$plot+guides(colour = guide_legend(nrow = 3,reverse = TRUE),fill="none")+
  scale_x_continuous(trans="log",breaks = c(1,3,10,30,100,300),limits=c(1,300))+
  theme(legend.text = element_text(size=40),
        legend.key = element_rect(fill = "transparent",colour ="transparent"),
        axis.text.x = element_text(size=30),
        axis.text.y = element_text(size=30),
        axis.title.x = element_text(size=45),
        axis.title.y = element_text(size=45))
# Out:
# Scale for 'x' is already present. Adding another scale for 'x', which will
# replace the existing scale.
# plot without title

# %%
hhr4<-hhr[sevm%in%c("Population control","Pneumonia")]
hhr4$sevm<-factor(hhr4$sevm)
options(repr.plot.width=40, repr.plot.height=15)
fit4 <- survfit(Surv(timetoevent, tb) ~ sevm, data = hhr4)
fig4<-ggsurvplot(
  fit4,
  data = hhr4, 
  fun ="cloglog",
  conf.int = TRUE,
  censor = FALSE,
  palette = safe_colorblind_palette,
  legend.labs = c("Population control (reference)", "Pneumonia"),
  legend.title = "",
  size=1.7,
  break.time.by = 30,
  legend= c(0.35,0.9),
  ggtheme = theme_classic()      # Change ggplot2 theme
)
fig4$plot+guides(colour = guide_legend(nrow = 2,reverse = TRUE),fill="none")+
  scale_x_continuous(trans="log",breaks = c(1,3,10,30,100,300),limits=c(1,300))+
  theme(legend.text = element_text(size=40),
        legend.key = element_rect(fill = "transparent",colour ="transparent"),
        axis.text.x = element_text(size=30),
        axis.text.y = element_text(size=30),
        axis.title.x = element_text(size=45),
        axis.title.y = element_text(size=45))
# Out:
# Scale for 'x' is already present. Adding another scale for 'x', which will
# replace the existing scale.
# plot without title

# %% [markdown]
# Schoenfeld residuals test

# %%
options(repr.plot.width=26, repr.plot.height=15)
ggcoxzph(cox.zph(coxm))
# Out:
# plot without title

# %%
ggcoxdiagnostics(coxm2, type = "martingale", linear.predictions = TRUE)
# Out:
# Warning message:
# “`gather_()` was deprecated in tidyr 1.2.0.
# ℹ Please use `gather()` instead.
# ℹ The deprecated feature was likely used in the survminer package.
#   Please report the issue at <https://github.com/kassambara/survminer/issues>.”
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.97165”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.97165”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  2.2119e-14”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 4.1537”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message:
# “Computation failed in `stat_smooth()`:
# NA/NaN/Inf in foreign function call (arg 5)”
# plot without title

# %%
gg_object <- plot(mod_cb,
                  hazard.params = list(xvar = "timetoevent",
                                       by = "sevm",
                                       alpha = 0.05, # 80% CI
                                       ylab = "Hazard",
                                       gg = TRUE))
# Out:
# Conditions used in construction of plot
# sevm: Population control / Pneumonia
# offset: 0

# %%
gg_object + 
  theme_classic()+
  theme(legend.position = c(0.3,0.8)) + 
  scale_y_continuous(trans = "log10")+
  scale_x_continuous(breaks = 1:10*30,limits = c(0,300))+
  guides(colour = guide_legend(nrow = 2))+
  labs(colour="",fill = "")+
  theme(legend.text = element_text(size=40),
        legend.key = element_rect(fill = "transparent",colour ="transparent"),
        axis.text.x = element_text(size=20),
        axis.text.y = element_text(size=20),
        axis.title.x = element_text(size=30),
        axis.title.y = element_text(size=30))
# Out:
# plot without title

# %%
hhsub<-hhr[sevm %in% c("Population control","Pneumonia")]
coxsubsev <- coxph(Surv(timetoevent, tb) ~ sevm+sex+age+hiv+dm+cancer+copd, data = hhsub)
summary(coxsubsev)
cox.zph(coxsubsev)
# Out:
# Call:
# coxph(formula = Surv(timetoevent, tb) ~ sevm + sex + age + hiv +
#     dm + cancer + copd, data = hhsub)
#
#   n= 3843229, number of events= 2498
#
#                                  coef exp(coef) se(coef)      z Pr(>|z|)
# sevmNegative control               NA        NA  0.00000     NA       NA
# sevmAsymptomatic                   NA        NA  0.00000     NA       NA
# sevmSymptomatic non-pneumonia      NA        NA  0.00000     NA       NA
# sevmPneumonia                 2.01887   7.52979  0.11830 17.066  < 2e-16 ***
# sexTRUE                       1.16597   3.20904  0.04528 25.752  < 2e-16 ***
# age41-60                      0.37639   1.45702  0.04871  7.727 1.10e-14 ***
# age>60                        0.41647   1.51660  0.05669  7.347 2.03e-13 ***
# hivTRUE                       2.10856   8.23636  0.09305 22.661  < 2e-16 ***
# dmTRUE                        0.91765   2.50339  0.05759 15.935  < 2e-16 ***
# cancerTRUE                    0.63377   1.88470  0.10080  6.287 3.23e-10 ***
# copdTRUE                      0.87654   2.40256  0.09587  9.143  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#                               exp(coef) exp(-coef) lower .95 upper .95
# sevmNegative control                 NA         NA        NA        NA
# sevmAsymptomatic                     NA         NA        NA        NA
# sevmSymptomatic non-pneumonia        NA         NA        NA        NA
# sevmPneumonia                     7.530     0.1328     5.972     9.495
# sexTRUE                           3.209     0.3116     2.937     3.507
# age41-60                          1.457     0.6863     1.324     1.603
# age>60                            1.517     0.6594     1.357     1.695
# hivTRUE                           8.236     0.1214     6.863     9.884
# dmTRUE                            2.503     0.3995     2.236     2.802
# cancerTRUE                        1.885     0.5306     1.547     2.296
# copdTRUE                          2.403     0.4162     1.991     2.899
#
# Concordance= 0.713  (se = 0.005 )
# Likelihood ratio test= 1785  on 8 df,   p=<2e-16
# Wald test            = 2242  on 8 df,   p=<2e-16
# Score (logrank) test = 2791  on 8 df,   p=<2e-16
#         chisq df       p
# sevm    0.907  1 0.34092
# sex     2.479  1 0.11535
# age     0.237  2 0.88831
# hiv     2.764  1 0.09641
# dm      1.883  1 0.17002
# cancer  6.454  1 0.01107
# copd    9.169  1 0.00246
# GLOBAL 26.317  8 0.00093

# %%
fit_sex <- survfit(Surv(timetoevent, tb) ~ sex, data = hhr)
ph_sex<-ggsurvplot(
  fit_sex,
  data = hhr,             # Add p-value
  fun ="cloglog",
  censor = FALSE,
  palette = safe_colorblind_palette,
  legend.title = "",
  size=1.7,
  legend= c(0.35,0.9),
  ggtheme = theme_classic()      # Change ggplot2 theme
)
ph_sex$plot+
  theme(legend.text = element_text(size=25),
        legend.key = element_rect(fill = "transparent",colour ="transparent"),
        axis.text.x = element_text(size=20),
        axis.text.y = element_text(size=20),
        axis.title.x = element_text(size=17),
        axis.title.y = element_text(size=17))
# Out:
# plot without title

# %%
fit_sex <- survfit(Surv(timetoevent, tb) ~ sex, data = hhr)
myfun=function(p){return(-log(-log(p)))}
ph_sex<-ggsurvplot(
  fit_sex,
  data = hhr,
  fun =myfun,
  censor = FALSE,
  palette = safe_colorblind_palette,
  legend.title = "",
  size=1.7,
  xlim=c(exp(1),300),
  legend= c(0.35,0.9),
  ggtheme = theme_classic()      # Change ggplot2 theme
)
ph_sex$plot+
scale_x_continuous(trans="log",breaks = c(1,3,10,30,100,300),limits=c(1,300))+
  theme(legend.text = element_text(size=25),
        legend.key = element_rect(fill = "transparent",colour ="transparent"),
        axis.text.x = element_text(size=20),
        axis.text.y = element_text(size=20),
        axis.title.x = element_text(size=17),
        axis.title.y = element_text(size=17))
# Out:
# Scale for 'x' is already present. Adding another scale for 'x', which will
# replace the existing scale.
#
# Warning message:
# “Transformation introduced infinite values in continuous x-axis”
# Warning message:
# “Transformation introduced infinite values in continuous x-axis”
# plot without title

# %%
fit_age <- survfit(Surv(timetoevent, tb) ~ age, data = hhr)
ph_age<-ggsurvplot(
  fit_age,
  data = hhr,             # Add p-value
  fun ="cloglog",
  censor = FALSE,
  palette = safe_colorblind_palette,
  legend.title = "",
  size=1.7,
  legend= c(0.35,0.9),
  ggtheme = theme_classic()      # Change ggplot2 theme
)
ph_age$plot+
  theme(legend.text = element_text(size=25),
        legend.key = element_rect(fill = "transparent",colour ="transparent"),
        axis.text.x = element_text(size=20),
        axis.text.y = element_text(size=20),
        axis.title.x = element_text(size=17),
        axis.title.y = element_text(size=17))
# Out:
# plot without title

# %%
fit_cancer <- survfit(Surv(timetoevent, tb) ~ cancer, data = hhr)
ph_cancer<-ggsurvplot(
  fit_cancer,
  data = hhr,             # Add p-value
  fun ="cloglog",
  censor = FALSE,
  palette = safe_colorblind_palette,
  legend.title = "",
  size=1.7,
  legend= c(0.35,0.9),
  ggtheme = theme_classic()      # Change ggplot2 theme
)
ph_cancer$plot+
  theme(legend.text = element_text(size=25),
        legend.key = element_rect(fill = "transparent",colour ="transparent"),
        axis.text.x = element_text(size=20),
        axis.text.y = element_text(size=20),
        axis.title.x = element_text(size=17),
        axis.title.y = element_text(size=17))
# Out:
# plot without title

# %%
fit_copd <- survfit(Surv(timetoevent, tb) ~ copd, data = hhr)
ph_copd<-ggsurvplot(
  fit_copd,
  data = hhr,             # Add p-value
  fun ="cloglog",
  censor = FALSE,
  palette = safe_colorblind_palette,
  legend.title = "",
  size=1.7,
  legend= c(0.35,0.9),
  ggtheme = theme_classic()      # Change ggplot2 theme
)
ph_copd$plot+
  theme(legend.text = element_text(size=25),
        legend.key = element_rect(fill = "transparent",colour ="transparent"),
        axis.text.x = element_text(size=20),
        axis.text.y = element_text(size=20),
        axis.title.x = element_text(size=17),
        axis.title.y = element_text(size=17))
# Out:
# plot without title

# %% [markdown]
# The model violated Cox's proportional hazard mainly due to sevm. Admission bias (Berkson's bias) lead to the surging of subsequent TB among patients with COVID-19. Therefore, we performed time-varying using time-spliting on the 30th day of follow up. The follow up period was divided into 2 groups: within 0–30 days of follow up and after that.

# %%
hhr2 <- survSplit(Surv(timetoevent, tb) ~ ., data= hhr, cut=c(30),
                 episode= "tgroup", id="newid")

hhr2$sevm<-factor(hhr2$sevm,levels = c("Pneumonia","Symptomatic non-pneumonia",
                                     "Asymptomatic","Negative control","Population control"))
coxfit2 <- survival::coxph(Surv(tstart, timetoevent, tb) ~ sevm:strata(tgroup)+sex+age+hiv+dm+cancer+copd, data=hhr2)
summary(coxfit2)
cox.zph(coxfit2)
# Out:
# Warning message in agreg.fit(X, Y, istrat, offset, init, control, weights = weights, :
# “Ran out of iterations and did not converge”
# Call:
# survival::coxph(formula = Surv(tstart, timetoevent, tb) ~ sevm:strata(tgroup) +
#     sex + age + hiv + dm + cancer + copd, data = hhr2)
#
#   n= 8557529, number of events= 2711
#
#                                                           coef exp(coef)
# sexTRUE                                               1.149074  3.155269
# age41-60                                              0.381758  1.464857
# age>60                                                0.423628  1.527493
# hivTRUE                                               2.133404  8.443557
# dmTRUE                                                0.914801  2.496277
# cancerTRUE                                            0.718435  2.051220
# copdTRUE                                              0.932864  2.541777
# sevmPneumonia:strata(tgroup)tgroup=1                  2.289948  9.874423
# sevmSymptomatic non-pneumonia:strata(tgroup)tgroup=1  1.090657  2.976228
# sevmAsymptomatic:strata(tgroup)tgroup=1              -0.004386  0.995623
# sevmNegative control:strata(tgroup)tgroup=1           0.458793  1.582164
# sevmPopulation control:strata(tgroup)tgroup=1               NA        NA
# sevmPneumonia:strata(tgroup)tgroup=2                  1.967222  7.150785
# sevmSymptomatic non-pneumonia:strata(tgroup)tgroup=2  1.348611  3.852071
# sevmAsymptomatic:strata(tgroup)tgroup=2               0.343343  1.409652
# sevmNegative control:strata(tgroup)tgroup=2          -0.034201  0.966378
# sevmPopulation control:strata(tgroup)tgroup=2               NA        NA
#                                                       se(coef)      z Pr(>|z|)
# sexTRUE                                               0.043258 26.563  < 2e-16
# age41-60                                              0.046705  8.174 2.99e-16
# age>60                                                0.054746  7.738 1.01e-14
# hivTRUE                                               0.087976 24.250  < 2e-16
# dmTRUE                                                0.055175 16.580  < 2e-16
# cancerTRUE                                            0.093153  7.712 1.23e-14
# copdTRUE                                              0.089609 10.410  < 2e-16
# sevmPneumonia:strata(tgroup)tgroup=1                  0.286092  8.004 1.20e-15
# sevmSymptomatic non-pneumonia:strata(tgroup)tgroup=1  0.710577  1.535   0.1248
# sevmAsymptomatic:strata(tgroup)tgroup=1               0.710615 -0.006   0.9951
# sevmNegative control:strata(tgroup)tgroup=1           0.195345  2.349   0.0188
# sevmPopulation control:strata(tgroup)tgroup=1         0.000000     NA       NA
# sevmPneumonia:strata(tgroup)tgroup=2                  0.129770 15.159  < 2e-16
# sevmSymptomatic non-pneumonia:strata(tgroup)tgroup=2  0.237181  5.686 1.30e-08
# sevmAsymptomatic:strata(tgroup)tgroup=2               0.219865  1.562   0.1184
# sevmNegative control:strata(tgroup)tgroup=2           0.087549 -0.391   0.6961
# sevmPopulation control:strata(tgroup)tgroup=2         0.000000     NA       NA
#
# sexTRUE                                              ***
# age41-60                                             ***
# age>60                                               ***
# hivTRUE                                              ***
# dmTRUE                                               ***
# cancerTRUE                                           ***
# copdTRUE                                             ***
# sevmPneumonia:strata(tgroup)tgroup=1                 ***
# sevmSymptomatic non-pneumonia:strata(tgroup)tgroup=1
# sevmAsymptomatic:strata(tgroup)tgroup=1
# sevmNegative control:strata(tgroup)tgroup=1          *
# sevmPopulation control:strata(tgroup)tgroup=1
# sevmPneumonia:strata(tgroup)tgroup=2                 ***
# sevmSymptomatic non-pneumonia:strata(tgroup)tgroup=2 ***
# sevmAsymptomatic:strata(tgroup)tgroup=2
# sevmNegative control:strata(tgroup)tgroup=2
# sevmPopulation control:strata(tgroup)tgroup=2
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#                                                      exp(coef) exp(-coef)
# sexTRUE                                                 3.1553     0.3169
# age41-60                                                1.4649     0.6827
# age>60                                                  1.5275     0.6547
# hivTRUE                                                 8.4436     0.1184
# dmTRUE                                                  2.4963     0.4006
# cancerTRUE                                              2.0512     0.4875
# copdTRUE                                                2.5418     0.3934
# sevmPneumonia:strata(tgroup)tgroup=1                    9.8744     0.1013
# sevmSymptomatic non-pneumonia:strata(tgroup)tgroup=1    2.9762     0.3360
# sevmAsymptomatic:strata(tgroup)tgroup=1                 0.9956     1.0044
# sevmNegative control:strata(tgroup)tgroup=1             1.5822     0.6320
# sevmPopulation control:strata(tgroup)tgroup=1               NA         NA
# sevmPneumonia:strata(tgroup)tgroup=2                    7.1508     0.1398
# sevmSymptomatic non-pneumonia:strata(tgroup)tgroup=2    3.8521     0.2596
# sevmAsymptomatic:strata(tgroup)tgroup=2                 1.4097     0.7094
# sevmNegative control:strata(tgroup)tgroup=2             0.9664     1.0348
# sevmPopulation control:strata(tgroup)tgroup=2               NA         NA
#                                                      lower .95 upper .95
# sexTRUE                                                 2.8988     3.434
# age41-60                                                1.3367     1.605
# age>60                                                  1.3721     1.701
# hivTRUE                                                 7.1062    10.033
# dmTRUE                                                  2.2404     2.781
# cancerTRUE                                              1.7089     2.462
# copdTRUE                                                2.1324     3.030
# sevmPneumonia:strata(tgroup)tgroup=1                    5.6362    17.299
# sevmSymptomatic non-pneumonia:strata(tgroup)tgroup=1    0.7393    11.981
# sevmAsymptomatic:strata(tgroup)tgroup=1                 0.2473     4.008
# sevmNegative control:strata(tgroup)tgroup=1             1.0789     2.320
# sevmPopulation control:strata(tgroup)tgroup=1               NA        NA
# sevmPneumonia:strata(tgroup)tgroup=2                    5.5449     9.222
# sevmSymptomatic non-pneumonia:strata(tgroup)tgroup=2    2.4199     6.132
# sevmAsymptomatic:strata(tgroup)tgroup=2                 0.9161     2.169
# sevmNegative control:strata(tgroup)tgroup=2             0.8140     1.147
# sevmPopulation control:strata(tgroup)tgroup=2               NA        NA
#
# Concordance= 0.715  (se = 0.005 )
# Likelihood ratio test= 1994  on 15 df,   p=<2e-16
# Wald test            = 2536  on 15 df,   p=<2e-16
# Score (logrank) test = 3179  on 15 df,   p=<2e-16
#                      chisq df       p
# sex                  3.004  1 0.08307
# age                  0.259  2 0.87836
# hiv                  2.344  1 0.12578
# dm                   1.122  1 0.28943
# cancer              10.161  1 0.00143
# copd                 6.267  1 0.01230
# sevm:strata(tgroup) 31.452  8 0.00012
# GLOBAL              56.605 15 9.6e-07

# %% [markdown]
# # Diagnostics for the Cox model (0-30 days after the inception)

# %%
hhr2<-hhr
hhr2[timetoevent>30]$tb<-FALSE
hhr2[timetoevent>30]$timetoevent<-30
hhr3<-hhr[timetoevent>30]
hhr3$timetoevent<-hhr3$timetoevent-30
coxm <- coxph(Surv(timetoevent, tb) ~ sevm+sex+age+hiv+dm+cancer+copd, data = hhr2)
summary(coxm)
x1<-cox.zph(coxm)
# Out:
# Call:
# coxph(formula = Surv(timetoevent, tb) ~ sevm + sex + age + hiv +
#     dm + cancer + copd, data = hhr2)
#
#   n= 4298873, number of events= 255
#
#                                   coef exp(coef) se(coef)      z Pr(>|z|)
# sevmNegative control           0.42943   1.53639  0.19574  2.194  0.02825 *
# sevmAsymptomatic              -0.04037   0.96043  0.71177 -0.057  0.95477
# sevmSymptomatic non-pneumonia  1.01895   2.77027  0.71135  1.432  0.15203
# sevmPneumonia                  2.21472   9.15881  0.28809  7.688 1.50e-14 ***
# sexTRUE                        0.90669   2.47611  0.13559  6.687 2.27e-11 ***
# age41-60                       0.39586   1.48566  0.15209  2.603  0.00925 **
# age>60                         0.18695   1.20557  0.18742  0.998  0.31852
# hivTRUE                        2.43128  11.37340  0.24781  9.811  < 2e-16 ***
# dmTRUE                         1.08833   2.96932  0.17035  6.389 1.67e-10 ***
# cancerTRUE                     0.70163   2.01703  0.30074  2.333  0.01965 *
# copdTRUE                       1.59411   4.92394  0.23359  6.824 8.83e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#                               exp(coef) exp(-coef) lower .95 upper .95
# sevmNegative control             1.5364    0.65088    1.0468     2.255
# sevmAsymptomatic                 0.9604    1.04120    0.2380     3.876
# sevmSymptomatic non-pneumonia    2.7703    0.36098    0.6871    11.169
# sevmPneumonia                    9.1588    0.10918    5.2074    16.109
# sexTRUE                          2.4761    0.40386    1.8983     3.230
# age41-60                         1.4857    0.67310    1.1027     2.002
# age>60                           1.2056    0.82949    0.8350     1.741
# hivTRUE                         11.3734    0.08792    6.9977    18.485
# dmTRUE                           2.9693    0.33678    2.1264     4.146
# cancerTRUE                       2.0170    0.49578    1.1187     3.637
# copdTRUE                         4.9239    0.20309    3.1152     7.783
#
# Concordance= 0.726  (se = 0.017 )
# Likelihood ratio test= 250  on 11 df,   p=<2e-16
# Wald test            = 384.8  on 11 df,   p=<2e-16
# Score (logrank) test = 543.3  on 11 df,   p=<2e-16

# %%
ggcoxzph(x1, font.main = 25)
# Out:
# plot without title

# %% [markdown]
# # Diagnostics for the Cox model (31-300 days after the inception)

# %%
coxm2 <- coxph(Surv(timetoevent, tb) ~ sevm+sex+age+hiv+dm+cancer+copd, data = hhr3)
summary(coxm2)
x2<-cox.zph(coxm2)
# Out:
# Call:
# coxph(formula = Surv(timetoevent, tb) ~ sevm + sex + age + hiv +
#     dm + cancer + copd, data = hhr3)
#
#   n= 4258656, number of events= 2456
#
#                                   coef exp(coef) se(coef)      z Pr(>|z|)
# sevmNegative control          -0.03167   0.96883  0.08756 -0.362    0.718
# sevmAsymptomatic               0.34726   1.41518  0.21990  1.579    0.114
# sevmSymptomatic non-pneumonia  1.35653   3.88270  0.23721  5.719 1.07e-08 ***
# sevmPneumonia                  1.97517   7.20787  0.12981 15.216  < 2e-16 ***
# sexTRUE                        1.17516   3.23868  0.04567 25.729  < 2e-16 ***
# age41-60                       0.37965   1.46178  0.04909  7.734 1.04e-14 ***
# age>60                         0.44724   1.56400  0.05722  7.816 5.46e-15 ***
# hivTRUE                        2.09575   8.13155  0.09416 22.257  < 2e-16 ***
# dmTRUE                         0.89526   2.44797  0.05834 15.345  < 2e-16 ***
# cancerTRUE                     0.72046   2.05538  0.09797  7.354 1.92e-13 ***
# copdTRUE                       0.84315   2.32366  0.09740  8.657  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#                               exp(coef) exp(-coef) lower .95 upper .95
# sevmNegative control             0.9688     1.0322    0.8161     1.150
# sevmAsymptomatic                 1.4152     0.7066    0.9197     2.178
# sevmSymptomatic non-pneumonia    3.8827     0.2576    2.4391     6.181
# sevmPneumonia                    7.2079     0.1387    5.5887     9.296
# sexTRUE                          3.2387     0.3088    2.9613     3.542
# age41-60                         1.4618     0.6841    1.3277     1.609
# age>60                           1.5640     0.6394    1.3981     1.750
# hivTRUE                          8.1315     0.1230    6.7612     9.780
# dmTRUE                           2.4480     0.4085    2.1835     2.745
# cancerTRUE                       2.0554     0.4865    1.6963     2.490
# copdTRUE                         2.3237     0.4304    1.9199     2.812
#
# Concordance= 0.714  (se = 0.005 )
# Likelihood ratio test= 1758  on 11 df,   p=<2e-16
# Wald test            = 2180  on 11 df,   p=<2e-16
# Score (logrank) test = 2695  on 11 df,   p=<2e-16

# %%
ggcoxzph(x2, font.main = 25)
# Out:
# plot without title

# %% [markdown]
# The model improved. However, we have to omit the remaining minimal violation for simplicity.

# %% [markdown]
# *Calculate incidence*

# %%
hhr$sevm<-factor(hhr$sevm,levels = c("Pneumonia","Symptomatic non-pneumonia",
                                     "Asymptomatic","Negative control","Population control"))
x1<-summary(pyears(Surv(timetoevent/365, tb) ~ sevm,data = hhr,scale = 1))
floor(x1$event/x1$pyears*100000)
r<-floor(x1$event/x1$pyears*100000)
se<-sqrt((1-r/100000)/x1$event)
lower<-floor(exp(log(r/100000)-qnorm(0.975)*se)*100000)
upper<-floor(exp(log(r/100000)+qnorm(0.975)*se)*100000)
x1f<-data.frame(inc=r,lower=lower,upper=upper)

x2<-summary(pyears(Surv(timetoevent/365, tb) ~ sevm,data = hhr2[hhr2$tgroup==1,],scale = 1))
floor(x2$event/x2$pyears*100000)
r<-floor(x2$event/x2$pyears*100000)
se<-sqrt((1-r/100000)/x2$event)
lower<-floor(exp(log(r/100000)-qnorm(0.975)*se)*100000)
upper<-floor(exp(log(r/100000)+qnorm(0.975)*se)*100000)
x2f<-data.frame(inc=r,lower=lower,upper=upper)
x2f

x3<-summary(pyears(Surv(timetoevent/365, tb) ~ sevm,data = hhr2[hhr2$tgroup==2,],scale = 1))
floor(x1$event/(x1$pyears-x2$pyears)*100000)
x1$pyears-x2$pyears
r<-floor(x3$event/(x1$pyears-x2$pyears)*100000)
se<-sqrt((1-r/100000)/x3$event)
lower<-floor(exp(log(r/100000)-qnorm(0.975)*se)*100000)
upper<-floor(exp(log(r/100000)+qnorm(0.975)*se)*100000)
x3f<-data.frame(inc=r,lower=lower,upper=upper)
x3f

x4<-summary(pyears(Surv(timetoevent/365, tb) ~ sex,data = hhr,scale = 1))
floor(x4$event/x4$pyears*100000)
r<-floor(x4$event/x4$pyears*100000)
se<-sqrt((1-r/100000)/x4$event)
lower<-floor(exp(log(r/100000)-qnorm(0.975)*se)*100000)
upper<-floor(exp(log(r/100000)+qnorm(0.975)*se)*100000)
x4f<-data.frame(inc=r,lower=lower,upper=upper)
x4f

x5<-summary(pyears(Surv(timetoevent/365, tb) ~ age,data = hhr,scale = 1))
r<-floor(x5$event/x5$pyears*100000)
se<-sqrt((1-r/100000)/x5$event)
lower<-floor(exp(log(r/100000)-qnorm(0.975)*se)*100000)
upper<-floor(exp(log(r/100000)+qnorm(0.975)*se)*100000)
x5f<-data.frame(inc=r,lower=lower,upper=upper)
x5f

x6<-summary(pyears(Surv(timetoevent/365, tb) ~ hiv,data = hhr,scale = 1))
r<-floor(x6$event/x6$pyears*100000)
se<-sqrt((1-r/100000)/x6$event)
lower<-floor(exp(log(r/100000)-qnorm(0.975)*se)*100000)
upper<-floor(exp(log(r/100000)+qnorm(0.975)*se)*100000)
x6f<-data.frame(inc=r,lower=lower,upper=upper)
x6f

x7<-summary(pyears(Surv(timetoevent/365, tb) ~ dm,data = hhr,scale = 1))
r<-floor(x7$event/x7$pyears*100000)
se<-sqrt((1-r/100000)/x7$event)
lower<-floor(exp(log(r/100000)-qnorm(0.975)*se)*100000)
upper<-floor(exp(log(r/100000)+qnorm(0.975)*se)*100000)
x7f<-data.frame(inc=r,lower=lower,upper=upper)
x7f

x8<-summary(pyears(Surv(timetoevent/365, tb) ~ copd,data = hhr,scale = 1))
r<-floor(x8$event/x8$pyears*100000)
se<-sqrt((1-r/100000)/x8$event)
lower<-floor(exp(log(r/100000)-qnorm(0.975)*se)*100000)
upper<-floor(exp(log(r/100000)+qnorm(0.975)*se)*100000)
x8f<-data.frame(inc=r,lower=lower,upper=upper)
x8f

x9<-summary(pyears(Surv(timetoevent/365, tb) ~ cancer,data = hhr,scale = 1))
r<-floor(x9$event/x9$pyears*100000)
se<-sqrt((1-r/100000)/x9$event)
lower<-floor(exp(log(r/100000)-qnorm(0.975)*se)*100000)
upper<-floor(exp(log(r/100000)+qnorm(0.975)*se)*100000)
x9f<-data.frame(inc=r,lower=lower,upper=upper)
x9f
# Out:
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sevm, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
#            sevm                 N      Events      Time
# --------------------------- --------- -------- ------------
#          Pneumonia             24617      75      14159.64
#  Symptomatic non-pneumonia     16935      20      10325.18
#        Asymptomatic            54286      23      34251.42
#      Negative control         384423     170     227917.62
#     Population control       3818612    2423    3108224.16
# sevm
#                 Pneumonia Symptomatic non-pneumonia              Asymptomatic
#                       529                       193                        67
#          Negative control        Population control
#                        74                        77
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sevm, data = hhr2[hhr2$tgroup ==
#     1, ], scale = 1)
#
# number of observations = 4298873
#
#            sevm                 N      Events      Time
# --------------------------- --------- -------- ------------
#          Pneumonia             24617     13       1972.838
#  Symptomatic non-pneumonia     16935      2       1388.792
#        Asymptomatic            54286      2       4457.997
#      Negative control         384423     30      29026.085
#     Population control       3818612    208     313812.745
# sevm
#                 Pneumonia Symptomatic non-pneumonia              Asymptomatic
#                       658                       144                        44
#          Negative control        Population control
#                       103                        66
#                           inc lower upper
# Pneumonia                 658 382   1131
# Symptomatic non-pneumonia 144  36    575
# Asymptomatic               44  11    175
# Negative control          103  72    147
# Population control         66  57     75
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sevm, data = hhr2[hhr2$tgroup ==
#     2, ], scale = 1)
#
# number of observations = 4258656
#
#            sevm                 N      Events      Time
# --------------------------- --------- -------- ------------
#          Pneumonia             23620      62      14128.17
#  Symptomatic non-pneumonia     16869      18      10322.88
#        Asymptomatic            54204      21      34248.55
#      Negative control         346655     140     227383.73
#     Population control       3817308    2215    3108162.75
# sevm
#                 Pneumonia Symptomatic non-pneumonia              Asymptomatic
#                       615                       223                        77
#          Negative control        Population control
#                        85                        86
# sevm
#                 Pneumonia Symptomatic non-pneumonia              Asymptomatic
#                 12186.803                  8936.392                 29793.422
#          Negative control        Population control
#                198891.537               2794411.411
#                           inc lower upper
# Pneumonia                 508 396   651
# Symptomatic non-pneumonia 201 126   318
# Asymptomatic               70  45   107
# Negative control           70  59    82
# Population control         79  75    82
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ sex, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
#   sex       N      Events    Time
# ------- --------- -------- ---------
#  FALSE   2332323     749    1836778
#  TRUE    1966550    1962    1558100
# sex
# FALSE  TRUE
#    40   125
#       inc lower upper
# FALSE  40  37    42
# TRUE  125 119   130
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ age, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
#   age       N      Events    Time
# ------- --------- -------- ---------
#  18-40   2011742     865    1580209
#  41-60   1435601    1075    1136834
#   >60     851530     771     677835
#       inc lower upper
# 18-40  54  50    57
# 41-60  94  88    99
# >60   113 105   121
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ hiv, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
#   hiv       N      Events      Time
# ------- --------- -------- ------------
#  FALSE   4274497    2572    3375716.75
#  TRUE      24376     139      19161.27
#       inc lower upper
# FALSE  76  73    78
# TRUE  725 614   855
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ dm, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
#   dm        N      Events     Time
# ------- --------- -------- -----------
#  FALSE   4021712    2261    3178673.8
#  TRUE     277161     450     216204.2
#       inc lower upper
# FALSE  71  68    73
# TRUE  208 189   228
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ copd, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
#  copd       N      Events      Time
# ------- --------- -------- ------------
#  FALSE   4247235    2569    3354787.54
#  TRUE      51638     142      40090.48
#       inc lower upper
# FALSE  76  73    78
# TRUE  354 300   417
# Call: pyears(formula = Surv(timetoevent/365, tb) ~ cancer, data = hhr,
#     scale = 1)
#
# number of observations = 4298873
#
#  cancer      N      Events      Time
# -------- --------- -------- ------------
#  FALSE    4220062    2586    3332890.38
#   TRUE      78811     125      61987.64
#       inc lower upper
# FALSE  77  74    80
# TRUE  201 168   239

# %% [markdown]
# # **Sensitivity analysis**

# %% [markdown]
# COVID-19 pneumonia versus population control within 0-30 days period

# %%
evalues.HR(9.1588, 5.2074, 16.109, rare = TRUE)
# Out:
#          point    lower    upper
# RR        9.15880 5.207400 16.109
# E-values 17.80315 9.888171     NA

# %% [markdown]
# COVID-19 pneumonia versus population control within 31-300 days period

# %%
evalues.HR(7.2079, 5.5887, 9.296, rare = TRUE)
# Out:
#          point    lower    upper
# RR        7.20790  5.58870 9.296
# E-values 13.89714 10.65278    NA
